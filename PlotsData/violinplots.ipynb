# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
df = pd.read_csv("violinplotsdb.csv", error_bad_lines=False, encoding="ISO-8859-1")
df
# Out:
#                       Benchmark Language  Energy (Joules)  Time (Seconds)  \
# 0     Sorting-remove_duplicates        C           21.890           1.647
# 1     Sorting-remove_duplicates        C           20.623           1.608
# 2     Sorting-remove_duplicates        C           21.521           1.635
# 3     Sorting-remove_duplicates        C           20.315           1.536
# 4     Sorting-remove_duplicates        C           19.546           1.487
# ...                         ...      ...              ...             ...
# 1795             Fannkuch-redux       JS         3119.482         207.589
# 1796             Fannkuch-redux       JS         3115.705         207.465
# 1797             Fannkuch-redux       JS         3124.956         208.894
# 1798             Fannkuch-redux       JS         3120.189         208.520
# 1799             Fannkuch-redux       JS         3122.508         208.276
#
#       Input
# 0     Small
# 1     Small
# 2     Small
# 3     Small
# ...

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
dfsrd = df.loc[df['Benchmark'] == 'Sorting-remove_duplicates']
sns.violinplot(x='Input', y='Energy (Joules)',hue='Language', data=dfsrd, linewidth=1).set_title("Sorting-remove_duplicates");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(x='Input', y='Time (Seconds)',hue='Language',ax=ax, data=dfsrd, linewidth=1).set_title("Sorting-remove_duplicates");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
dfsq = df.loc[df['Benchmark'] == 'Sorting-quick']
sns.violinplot(x='Input', y='Energy (Joules)',hue='Language', data=dfsq, linewidth=1).set_title("Sorting-quick");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(x='Input', y='Time (Seconds)',hue='Language',ax=ax, data=dfsq, linewidth=1).set_title("Sorting-quick");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
dfsn = df.loc[df['Benchmark'] == 'Sorting-natural']
sns.violinplot(x='Input', y='Energy (Joules)',hue='Language', data=dfsn, linewidth=1).set_title("Sorting-natural");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(x='Input', y='Time (Seconds)',hue='Language',ax=ax, data=dfsn, linewidth=1).set_title("Sorting-natural");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
dfsm = df.loc[df['Benchmark'] == 'Sorting-merge']
sns.violinplot(x='Input', y='Energy (Joules)',hue='Language', data=dfsm, linewidth=1).set_title("Sorting-merge");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(x='Input', y='Time (Seconds)',hue='Language',ax=ax, data=dfsm, linewidth=1).set_title("Sorting-merge");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
dfsl = df.loc[df['Benchmark'] == 'Sorting-lexicographically']
sns.violinplot(x='Input', y='Energy (Joules)',hue='Language', data=dfsl, linewidth=1).set_title("Sorting-lexicographically");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(x='Input', y='Time (Seconds)',hue='Language',ax=ax, data=dfsl, linewidth=1).set_title("Sorting-lexicographically");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
dfsi = df.loc[df['Benchmark'] == 'Sorting-identifiers']
sns.violinplot(x='Input', y='Energy (Joules)',hue='Language', data=dfsi, linewidth=1).set_title("Sorting-identifiers");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(x='Input', y='Time (Seconds)',hue='Language',ax=ax, data=dfsi, linewidth=1).set_title("Sorting-identifiers");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
dfsc = df.loc[df['Benchmark'] == 'Sorting-circle']
sns.violinplot(x='Input', y='Energy (Joules)',hue='Language', data=dfsc, linewidth=1).set_title("Sorting-circle");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(x='Input', y='Time (Seconds)',hue='Language',ax=ax, data=dfsc, linewidth=1).set_title("Sorting-circle");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
dfsb = df.loc[df['Benchmark'] == 'Sorting-bead']
sns.violinplot(x='Input', y='Energy (Joules)',hue='Language', data=dfsb, linewidth=1).set_title("Sorting-bead");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(x='Input', y='Time (Seconds)',hue='Language',ax=ax, data=dfsb, linewidth=1).set_title("Sorting-bead");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
dffasta = df.loc[df['Benchmark'] == 'Fasta']
sns.violinplot(x='Input', y='Energy (Joules)',hue='Language', data=dffasta, linewidth=1).set_title("Fasta");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(x='Input', y='Time (Seconds)',hue='Language',ax=ax, data=dffasta, linewidth=1).set_title("Fasta");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
dffann = df.loc[df['Benchmark'] == 'Fannkuch-redux']
sns.violinplot(x='Input', y='Energy (Joules)',hue='Language', data=dffann, linewidth=1).set_title("Fannkuch-redux");

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(x='Input', y='Time (Seconds)',hue='Language',ax=ax, data=dffann, linewidth=1).set_title("Fannkuch-redux");
